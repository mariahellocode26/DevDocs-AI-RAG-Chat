# %%
import sys

print(sys.executable)
# Out:
# /workspaces/DevDocs-AI-RAG-Chat/.venv/bin/python

# %%
import rag
# Out:
# Loading embedding model: all-MiniLM-L6-v2
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Loading chunks_with_embeddings.json...
# Loaded 68 chunks
# Embedding matrix shape: (68, 384)

# %%
question = "What is the recommended way to store an OpenAI API key in Python applications?"

# %%
result_baseline = rag.rag(
    question,
    prompt_name="baseline"
)

print(result_baseline["answer"])
# Out:
# The recommended way is to store the API key in an environment variable, such as `OPENAI_API_KEY`, and read it in Python with `os.environ`:
#
# ```bash
# export OPENAI_API_KEY="your_api_key"
# ```
#
# ```python
# import os
# from openai import OpenAI
#
# client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])
# ```

# %%
result_strict = rag.rag(
    question,
    prompt_name="strict_grounding"
)

print(result_strict["answer"])
# Out:
# Store the API key securely using an environment variable, then read it in Python with `os.environ["OPENAI_API_KEY"]`.

# %%
print("=== BASELINE ===")
print(result_baseline["answer"])

print("\n=== STRICT GROUNDING ===")
print(result_strict["answer"])
# Out:
# === BASELINE ===
# The recommended way is to store the API key in an environment variable, such as `OPENAI_API_KEY`, and read it in Python with `os.environ`:
#
# ```bash
# export OPENAI_API_KEY="your_api_key"
# ```
#
# ```python
# import os
# from openai import OpenAI
#
# client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])
# ```
#
#
#
# === STRICT GROUNDING ===
# Store the API key securely using an environment variable, then read it in Python with `os.environ["OPENAI_API_KEY"]`.
