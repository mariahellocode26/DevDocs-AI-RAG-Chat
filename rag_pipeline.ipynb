# %%
# Data ingestion script for the project
# !python ingest.py
# Out:
# Loading Markdown files...
# Loaded 6 documents
# Chunking documents...
# Created 68 chunks
# Preparing text for embeddings...
# Saving processed chunks...
# Saved 68 chunks to processed_chunks.json
# Ingestion complete!
